# %% [markdown]
# # Manipulace s datovými strukturami

# %% [markdown]
# ## Import

# %% [markdown]
# Import modulů, které potřebujeme pro běh programu

# %%
import yaml

# %% [markdown]
# ## Definice konstant

# %% [markdown]
# Předdefinované konstanty používáme všude tam, kde se nějaká hodnota v programu opakuje nebo ji budeme používat pro výběr, porovnání atd.
# Proč?
# - IDE nám napovídá a tím kontroluje použití
# - v případě nutnosti změny stačí změnit hodnotu na jednom místě
# - konstanty můžeme sdílet mezi moduly aplikace
# - jejich použitím v referencích a porovnání předejdeš chybám, které se obtížně hledají

# %%
KEY_NAME = 'jmeno'
KEY_ALIAS = 'alias'
KEY_LECTORS = 'lektori'
KEY_STUDENTS = 'studenti'

KEY_HOBBY = 'zajmy'
KEY_JOB = 'prace'

# %% [markdown]
# ## Náš kurz

# %%
pcsda = { KEY_NAME:'DA Python',KEY_ALIAS: 'DAPYTPCS'}
pcsda
# Out:
# {'jmeno': 'DA Python', 'alias': 'DAPYTPCS'}

# %% [markdown]
# ### Učitelé

# %%
martinr = {KEY_NAME: 'Martin Rosicky',KEY_ALIAS:'MartinR'}
martinr
# Out:
# {'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}

# %% [markdown]
# ### Studenti

# %%
gabi = {KEY_NAME:'Gabca Miskova',KEY_ALIAS: 'Gabca'}
lukas = {KEY_NAME:'Lukas Pavlovec',KEY_ALIAS: 'Lukas'}
julia = {KEY_NAME:'Julia Tasci',KEY_ALIAS: 'Julia'}
stepan = {KEY_NAME:'Stepan Kucera',KEY_ALIAS: 'Kucis'}

# %% [markdown]
# ### Vše v jednom

# %% [markdown]
# Vložíme do `pcsda` seznam `list` učitelů a studentů

# %%
pcsda[KEY_LECTORS] = [martinr]
pcsda[KEY_STUDENTS] = [gabi,lukas,stepan,julia]
pcsda
# Out:
# {'jmeno': 'DA Python',
#  'alias': 'DAPYTPCS',
#  'lektori': [{'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}],
#  'studenti': [{'jmeno': 'Gabca Miskova', 'alias': 'Gabca'},
#   {'jmeno': 'Lukas Pavlovec', 'alias': 'Lukas'},
#   {'jmeno': 'Stepan Kucera', 'alias': 'Kucis'},
#   {'jmeno': 'Julia Tasci', 'alias': 'Julia'}]}

# %% [markdown]
# #### Rychlé formátování výstupu

# %% [markdown]
# YAML je formát prezentace dat snadno čitelný pro člověka i program

# %%
print(yaml.dump(pcsda))
# Out:
# alias: DAPYTPCS
# jmeno: DA Python
# lektori:
# - alias: MartinR
#   jmeno: Martin Rosicky
# studenti:
# - alias: Gabca
#   jmeno: Gabca Miskova
# - alias: Lukas
#   jmeno: Lukas Pavlovec
# - alias: Kucis
#   jmeno: Stepan Kucera
# - alias: Julia
#   jmeno: Julia Tasci

# %% [markdown]
# #### Vytvoříme kompletní seznam

# %%
we_all = pcsda.get(KEY_LECTORS) + pcsda.get(KEY_STUDENTS)
print(yaml.dump(we_all))
# Out:
# - alias: MartinR
#   jmeno: Martin Rosicky
#   zajmy: uceni
# - alias: Gabca
#   jmeno: Gabca Miskova
#   prace: kvalita
# - alias: Lukas
#   jmeno: Lukas Pavlovec
#   prace: chemik
# - alias: Kucis
#   jmeno: Stepan Kucera
#   zajmy: hokej
# - alias: Julia
#   jmeno: Julia Tasci
#   zajmy: kvizy

# %% [markdown]
# ### Procházení seznamů

# %% [markdown]
# #### Cyklus `for ... in ...:`
# prochází `list` polozku po položce

# %%
for osoba in we_all:
    print(osoba)
    print(osoba.get(KEY_ALIAS))

print('to je wse')
# Out:
# {'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}
# MartinR
# {'jmeno': 'Gabca Miskova', 'alias': 'Gabca'}
# Gabca
# {'jmeno': 'Lukas Pavlovec', 'alias': 'Lukas'}
# Lukas
# {'jmeno': 'Stepan Kucera', 'alias': 'Kucis'}
# Kucis
# {'jmeno': 'Julia Tasci', 'alias': 'Julia'}
# Julia
# to je wse

# %% [markdown]
# #### Podle indexu
# - `len(list)` délka seznamu
# - `range(a,b)` vrátí řadu čísel od `a` do `b-1`

# %%
for ii in range(0,len(we_all)):
    print(ii,we_all[ii])
# Out:
# 0 {'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}
# 1 {'jmeno': 'Gabca Miskova', 'alias': 'Gabca'}
# 2 {'jmeno': 'Lukas Pavlovec', 'alias': 'Lukas'}
# 3 {'jmeno': 'Stepan Kucera', 'alias': 'Kucis'}
# 4 {'jmeno': 'Julia Tasci', 'alias': 'Julia'}

# %% [markdown]
# ### Procházení slovníků

# %% [markdown]
# získání seznamu klíčů

# %%
for key in pcsda.keys():
    print(key,pcsda.get(key),sep=': ')
# Out:
# jmeno: DA Python
# alias: DAPYTPCS
# lektori: [{'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}]
# studenti: [{'jmeno': 'Gabca Miskova', 'alias': 'Gabca'}, {'jmeno': 'Lukas Pavlovec', 'alias': 'Lukas'}, {'jmeno': 'Stepan Kucera', 'alias': 'Kucis'}, {'jmeno': 'Julia Tasci', 'alias': 'Julia'}]

# %% [markdown]
# získání hodnot

# %%
for val in pcsda.values():
    print(val)
# Out:
# DA Python
# DAPYTPCS
# [{'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}]
# [{'jmeno': 'Gabca Miskova', 'alias': 'Gabca'}, {'jmeno': 'Lukas Pavlovec', 'alias': 'Lukas'}, {'jmeno': 'Stepan Kucera', 'alias': 'Kucis'}, {'jmeno': 'Julia Tasci', 'alias': 'Julia'}]

# %% [markdown]
# ziskani polozek

# %%
for key,val in pcsda.items():
    print(f'{key}: {val}')
# Out:
# jmeno: DA Python
# alias: DAPYTPCS
# lektori: [{'jmeno': 'Martin Rosicky', 'alias': 'MartinR'}]
# studenti: [{'jmeno': 'Gabca Miskova', 'alias': 'Gabca'}, {'jmeno': 'Lukas Pavlovec', 'alias': 'Lukas'}, {'jmeno': 'Stepan Kucera', 'alias': 'Kucis'}, {'jmeno': 'Julia Tasci', 'alias': 'Julia'}]

# %% [markdown]
# vytvoříme tabulku

# %%
martinr[KEY_HOBBY] = 'uceni'
gabi[KEY_JOB] = 'kvalita'
lukas[KEY_JOB] = 'chemik'
julia[KEY_HOBBY] = 'kvizy'
stepan[KEY_HOBBY] = 'hokej'

print(yaml.dump(pcsda))
# Out:
# alias: DAPYTPCS
# jmeno: DA Python
# lektori:
# - alias: MartinR
#   jmeno: Martin Rosicky
#   zajmy: uceni
# studenti:
# - alias: Gabca
#   jmeno: Gabca Miskova
#   prace: kvalita
# - alias: Lukas
#   jmeno: Lukas Pavlovec
#   prace: chemik
# - alias: Kucis
#   jmeno: Stepan Kucera
#   zajmy: hokej
# - alias: Julia
#   jmeno: Julia Tasci
#   zajmy: kvizy

# %%
print('\t\t'.join(we_all[0].keys()))
print('-'*50)
for osoba in we_all:
    print('\t'.join(osoba.values()))
# Out:
# jmeno		alias		zajmy
# --------------------------------------------------
# Martin Rosicky	MartinR	uceni
# Gabca Miskova	Gabca	kvalita
# Lukas Pavlovec	Lukas	chemik
# Stepan Kucera	Kucis	hokej
# Julia Tasci	Julia	kvizy

# %% [markdown]
# zjistíme si všechny hlavičky a vytvorime tabulku znovu

# %%
headers = set()
for pp in we_all:
    #print(pp.keys())
    #headers = headers | pp.keys()
    headers |= pp.keys()

headers
# Out:
# {'alias', 'jmeno', 'prace', 'zajmy'}

# %%
headers = list(headers)
headers.sort()

print('\t\t'.join(headers))
print('-'*60)
for osoba in we_all:
    #print('\t'.join(osoba.values()))
    row = []
    for head in headers:
        row.append(osoba.get(head,'-'*5))
    print('\t'.join(row))
# Out:
# prace		zajmy		alias		jmeno
# ------------------------------------------------------------
# -----	uceni	MartinR	Martin Rosicky
# kvalita	-----	Gabca	Gabca Miskova
# chemik	-----	Lukas	Lukas Pavlovec
# -----	hokej	Kucis	Stepan Kucera
# -----	kvizy	Julia	Julia Tasci
